# %% [markdown]
# ## Internal Project Grouop 9 - Retail Sales
#
# Hello World!
#
# We will be analysing the past sales data to reveal useful data insights that could benefit our clients.

# %% [markdown]
# #### Importing Libraries
# Do pip install commands before the import commands if you have yet to install the libraries

# %%
# uncomment the following pip install commands where needed
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

import pandas as pd         # data manipulation & analysis
import numpy as np          # numerical & mathematical operations
import matplotlib.pyplot as plt         # for creating visualisations
import seaborn as  sns          # for more advanced visualisations 
from matplotlib.ticker import ScalarFormatter # Format labels into more readable format

# %% [markdown]
# #### Reading data into dataframe

# %%
df = pd.read_csv('datasets/Retail_Store.csv' , encoding='latin-1') #latin-1 encoding to deal with decoding error

# %% [markdown]
# #### Take a look at the data O.O
# Understanding the data before we proceed with further analysis. <br/>
# Viewing df in Data Wrangler will allow us to see the full data.

# %%
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# 1                   1           73  Sporting Goods        Caguas  ...
# 2                   0           73  Sporting Goods      San Jose  ...
# 3                   0           73  Sporting Goods   Los Angeles  ...
# 4                   0           73  Sporting Goods        Caguas  ...
#
#   Order Zipcode Product Card Id Product Category Id  Product Description  \
# 0           NaN            1360                  73                  NaN
# 1           NaN            1360                  73                  NaN
# 2           NaN            1360                  73                  NaN
# 3           NaN            1360                  73                  NaN
# 4           NaN            1360                  73                  NaN
#
#                                   Product Image  Product Name Product Price  \
# 0  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 1  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 2  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 3  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 4  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
#
#   Product Status shipping date (DateOrders)   Shipping Mode
# 0              0             2/3/2018 22:56  Standard Class
# 1              0            1/18/2018 12:27  Standard Class
# 2              0            1/17/2018 12:06  Standard Class
# 3              0            1/16/2018 11:45  Standard Class
# 4              0            1/15/2018 11:24  Standard Class
#
# [5 rows x 53 columns]

# %%
# Finding number of columns and rows
print("The original dataset contains", df.shape[1],"Columns and", df.shape[0],"Rows.")
# Out:
# The original dataset contains 53 Columns and 180519 Rows.

# %%
# Checking for missing values
def col_missing_values(df):
    for i in df.columns:
        if df[i].isna().sum()>0:
            print("Column",i,"is missing",str(df[i].isna().sum()),"values.")

col_missing_values(df)
# Out:
# Column Customer Lname is missing 8 values.
# Column Customer Zipcode is missing 3 values.
# Column Order Zipcode is missing 155679 values.
# Column Product Description is missing 180519 values.

# %%
#Checking for duplicated rows
duplicate_rows_df = df[df.duplicated()]

print("Number of duplicate rows: ", duplicate_rows_df.shape[0])
# Out:
# Number of duplicate rows:  0

# %%
# Check for columns with identical values
duplicated_columns = df.T.duplicated()

# Display names of duplicated columns
duplicate_columns = df.columns[duplicated_columns].tolist()
print("Duplicate columns:", duplicate_columns)
# Out:
# Duplicate columns: ['Customer Password', 'Order Customer Id', 'Order Item Total', 'Order Profit Per Order', 'Product Card Id', 'Product Category Id', 'Product Price']

# %% [markdown]
# From the codes above, we have decided to drop:
# * Columns with missing data <br/>
#         -- Reason being it holds little value to our investigation
# * Duplicate Columns
# * Other columns we deem carry insignificant information

# %%
df = df.drop(columns=['Customer Lname','Customer Zipcode','Order Zipcode','Product Description',
                      'Customer Password','Order Customer Id','Order Item Total','Order Profit Per Order',
                      'Product Card Id','Product Category Id','Product Price','Customer Fname',
                      'Product Description','Customer Email','Product Image','Product Status',
                      'Order Id','Order Item Id','Order Item Cardprod Id'])

# %%
# Dropped 18 Columns
df.shape
# Out:
# (180519, 35)

# %% [markdown]
# #### Converting and Filtering of data
#
# Coverting DateOrders column to DateTime format using Pandas to perform trend analysis

# %%
df['order_date'] = pd.to_datetime(df['order date (DateOrders)'])
df['year'] = df['order_date'].dt.year
df['month'] = df['order_date'].dt.month

print(df['order_date'])
# Out:
# 0        2018-01-31 22:56:00
# 1        2018-01-13 12:27:00
# 2        2018-01-13 12:06:00
# 3        2018-01-13 11:45:00
# 4        2018-01-13 11:24:00
#                  ...
# 180514   2016-01-16 03:40:00
# 180515   2016-01-16 01:34:00
# 180516   2016-01-15 21:00:00
# 180517   2016-01-15 20:18:00
# 180518   2016-01-15 18:54:00
# Name: order_date, Length: 180519, dtype: datetime64[ns]

# %% [markdown]
# Note: Year 2018 only has data up till month of January <br/>
# Due to incomplete data of year 2018, there is insufficient data for comprehensive analysis. We will drop this year.

# %%
# Drop rows where 'year' is 2018
df_filter_year = df[df['year'] != 2018]

# Preview the filtered dataset
df_filter_year.head(3)
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 48  PAYMENT                         5                              2
# 49  PAYMENT                         2                              2
# 50  PAYMENT                         6                              2
#
#     Benefit per order  Sales per customer   Delivery Status  \
# 48         -30.750000              115.18     Late delivery
# 49        -122.730003               79.18  Shipping on time
# 50          33.599998               96.00     Late delivery
#
#     Late_delivery_risk  Category Id    Category Name Customer City  ...  \
# 48                   1           17           Cleats       Bayamon  ...
# 49                   0           29    Shop By Sport        Caguas  ...
# 50                   1           24  Women's Apparel        Caguas  ...
#
#          Sales  Order Region        Order State     Order Status  \
# 48  119.980003    South Asia      Uttar Pradesh  PENDING_PAYMENT
# 49   79.980003     West Asia              Bursa  PENDING_PAYMENT
# 50  100.000000       Oceania  Australia del Sur  PENDING_PAYMENT
#
#                                      Product Name  shipping date (DateOrders)  \
# 48               Perfect Fitness Perfect Rip Deck             2/29/2016 13:57
# 49  Under Armour Girls' Toddler Spine Surge Runni            10/27/2016 14:39
# 50           Nike Men's Dri-FIT Victory Golf Polo               4/5/2016 4:37
#
#    Shipping Mode          order_date  year month
# 48  Second Class 2016-02-24 13:57:00  2016     2
# 49  Second Class 2016-10-25 14:39:00  2016    10
# 50  Second Class 2016-03-30 04:37:00  2016     3
#
# [3 rows x 38 columns]

# %% [markdown]
# Looking at unique data for columns of interest

# %%
print("Order Status :", df['Order Status'].unique())
print("\nMarket:", df['Market'].unique())

print("\nDepartment Name:", df['Department Name'].unique())
print("\nProduct Category:", df['Category Name'].unique())

print("\nDelivery Status :", df['Delivery Status'].unique())
print("\nShipping Mode :", df['Shipping Mode'].unique())
# Out:
# Order Status : ['COMPLETE' 'PENDING' 'CLOSED' 'PENDING_PAYMENT' 'CANCELED' 'PROCESSING'
#  'SUSPECTED_FRAUD' 'ON_HOLD' 'PAYMENT_REVIEW']
#
# Market: ['Pacific Asia' 'USCA' 'Africa' 'Europe' 'LATAM']
#
# Department Name: ['Fitness' 'Apparel' 'Golf' 'Footwear' 'Outdoors' 'Fan Shop' 'Technology'
#  'Book Shop' 'Discs Shop' 'Pet Shop' 'Health and Beauty ']
#
# Product Category: ['Sporting Goods' 'Cleats' 'Shop By Sport' "Women's Apparel" 'Electronics'
#  'Boxing & MMA' 'Cardio Equipment' 'Trade-In' "Kids' Golf Clubs"
#  'Hunting & Shooting' 'Baseball & Softball' "Men's Footwear"
#  'Camping & Hiking' 'Consumer Electronics' 'Cameras ' 'Computers'
#  'Basketball' 'Soccer' "Girls' Apparel" 'Accessories' "Women's Clothing"
#  'Crafts' "Men's Clothing" 'Tennis & Racquet' 'Fitness Accessories'
#  'As Seen on  TV!' 'Golf Balls' 'Strength Training' "Children's Clothing"
#  'Lacrosse' 'Baby ' 'Fishing' 'Books ' 'DVDs' 'CDs ' 'Garden' 'Hockey'
#  'Pet Supplies' 'Health and Beauty' 'Music' 'Video Games' 'Golf Gloves'
#  'Golf Bags & Carts' 'Golf Shoes' 'Golf Apparel' "Women's Golf Clubs"
#  "Men's Golf Clubs" 'Toys' 'Water Sports' 'Indoor/Outdoor Games']
#
# Delivery Status : ['Advance shipping' 'Late delivery' 'Shipping on time' 'Shipping canceled']
#
# Shipping Mode : ['Standard Class' 'First Class' 'Second Class' 'Same Day']

# %% [markdown]
# Only interested in 'CLOSED' and 'COMPLETED' orders <br/>
# * Other Order Status (e.g. PENDING_PAYMENT, ON_HOLD) includes uncertainty in analysing actual revenue earned.
# * Assumption made: CLOSED means payment is made

# %%
# Further filter to include only 'CLOSED' and 'COMPLETED' in 'Order Status'
df_filter_order = df_filter_year[df_filter_year['Order Status'].isin(['CLOSED', 'COMPLETED'])]

# %%
# Renaming dataframe to make life easier

df1 = df_filter_order
df1
# Out:
#         Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 1174    CASH                         2                              1
# 1177    CASH                         3                              4
# 1188    CASH                         2                              2
# 1191    CASH                         2                              1
# 1198    CASH                         2                              4
# ...      ...                       ...                            ...
# 180467  CASH                         2                              1
# 180496  CASH                         2                              4
# 180498  CASH                         3                              4
# 180504  CASH                         3                              4
# 180514  CASH                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# 1174            78.660004          262.200012     Late delivery
# 1177           109.669998          324.470001  Advance shipping
# 1188           136.509995          278.589996  Shipping on time
# 1191            23.650000          268.760010     Late delivery
# 1198            31.459999          314.640015  Advance shipping
# ...                   ...                 ...               ...
# 180467          27.900000          371.980011     Late delivery
# 180496         145.190002          399.980011  Advance shipping
# 180498        -337.100006          391.980011  Advance shipping
# 180504          32.029999          363.980011  Advance shipping
# 180514          40.000000          399.980011  Shipping on time
#
#         Late_delivery_risk  Category Id   Category Name  Customer City  ...  \
# 1174                     1           73  Sporting Goods         Caguas  ...
# 1177                     0           73  Sporting Goods          Tampa  ...
# 1188                     0           73  Sporting Goods      Irvington  ...
# 1191                     1           73  Sporting Goods        Gardena  ...
# 1198                     0           73  Sporting Goods        Ontario  ...
# ...                    ...          ...             ...            ...  ...
# 180467                   1           45         Fishing  Panorama City  ...
# 180496                   0           45         Fishing     Costa Mesa  ...
# 180498                   0           45         Fishing    Lindenhurst  ...
# 180504                   0           45         Fishing         Caguas  ...
# 180514                   0           45         Fishing       Brooklyn  ...
#
#              Sales    Order Region                           Order State  \
# 1174    327.750000  Southeast Asia                               Yakarta
# 1177    327.750000  Southeast Asia                               Yakarta
# 1188    327.750000  Southeast Asia                                Rangún
# 1191    327.750000  Southeast Asia                                Rangún
# 1198    327.750000  Southeast Asia                      Capital Nacional
# ...            ...             ...                                   ...
# 180467  399.980011      South Asia                           Maharashtra
# 180496  399.980011    Eastern Asia                              Shanghái
# 180498  399.980011  Southeast Asia                    Sumatra Meridional
# 180504  399.980011         Oceania  Territorio de la Capital Australiana
# 180514  399.980011    Eastern Asia                              Shanghái
#
#        Order Status                               Product Name  \
# 1174         CLOSED                               Smart watch
# 1177         CLOSED                               Smart watch
# 1188         CLOSED                               Smart watch
# 1191         CLOSED                               Smart watch
# 1198         CLOSED                               Smart watch
# ...             ...                                        ...
# 180467       CLOSED  Field & Stream Sportsman 16 Gun Fire Safe
# 180496       CLOSED  Field & Stream Sportsman 16 Gun Fire Safe
# 180498       CLOSED  Field & Stream Sportsman 16 Gun Fire Safe
# 180504       CLOSED  Field & Stream Sportsman 16 Gun Fire Safe
# 180514       CLOSED  Field & Stream Sportsman 16 Gun Fire Safe
#
#         shipping date (DateOrders)   Shipping Mode          order_date  year  \
# 1174               12/6/2017 14:37     First Class 2017-12-04 14:37:00  2017
# 1177               12/7/2017 13:34  Standard Class 2017-12-04 13:34:00  2017
# 1188                12/6/2017 9:43    Second Class 2017-12-04 09:43:00  2017
# 1191                12/6/2017 8:39     First Class 2017-12-04 08:39:00  2017
# 1198                12/6/2017 6:12  Standard Class 2017-12-04 06:12:00  2017
# ...                            ...             ...                 ...   ...
# 180467             1/20/2016 19:05     First Class 2016-01-18 19:05:00  2016
# 180496             1/18/2016 22:14  Standard Class 2016-01-16 22:14:00  2016
# 180498             1/19/2016 19:05  Standard Class 2016-01-16 19:05:00  2016
# 180504             1/19/2016 13:49  Standard Class 2016-01-16 13:49:00  2016
# 180514              1/20/2016 3:40  Standard Class 2016-01-16 03:40:00  2016
#
#        month
# 1174      12
# 1177      12
# 1188      12
# 1191      12
# 1198      12
# ...      ...
# 180467     1
# 180496     1
# 180498     1
# 180504     1
# 180514     1
#
# [19369 rows x 38 columns]

# %%
# Calculating revenue manually: Revenue = Price * Quantity
df1['Revenue'] = df1['Order Item Product Price'] * df1['Order Item Quantity']
annual_revenue = df1.groupby('year')['Revenue'].sum()
# Adjust display format (without scientific notation)
pd.set_option('display.float_format', '{:,.2f}'.format)
print(annual_revenue)
# Out:
# year
# 2015   1,402,915.38
# 2016   1,314,538.49
# 2017   1,267,870.46
# Name: Revenue, dtype: float64
# C:\Users\ameli\AppData\Local\Temp\ipykernel_19720\147296267.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Revenue'] = df1['Order Item Product Price'] * df1['Order Item Quantity']

# %%
df1['YearMonth'] = df1['order_date'].dt.to_period('M')
monthly_revenue = df1.groupby('YearMonth')['Revenue'].sum()

print(monthly_revenue)
# Out:
# YearMonth
# 2015-01   109,443.40
# 2015-02   110,744.91
# 2015-03   125,005.10
# 2015-04   113,800.59
# 2015-05   113,448.88
# 2015-06   112,993.33
# 2015-07   122,438.37
# 2015-08   112,923.54
# 2015-09   122,410.50
# 2015-10   108,236.25
# 2015-11   123,616.55
# 2015-12   127,853.93
# 2016-01   107,561.77
# 2016-02   106,892.23
# 2016-03   101,949.21
# 2016-04   120,345.24
# 2016-05   108,181.00
# 2016-06   115,606.76
# 2016-07   106,598.29
# 2016-08   104,456.39
# 2016-09   108,596.06
# 2016-10   124,286.01
# 2016-11   103,795.96
# 2016-12   106,269.55
# 2017-01   110,326.28
# 2017-02   109,808.68
# 2017-03   117,815.43
# 2017-04   116,043.70
# 2017-05   121,010.05
# 2017-06    96,483.92
# 2017-07   116,389.78
# 2017-08    99,145.51
# 2017-09   124,752.32
# 2017-10   116,520.78
# 2017-11    75,568.90
# 2017-12    64,005.09
# Freq: M, Name: Revenue, dtype: float64
# C:\Users\ameli\AppData\Local\Temp\ipykernel_19720\1903432295.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['YearMonth'] = df1['order_date'].dt.to_period('M')

# %% [markdown]
# #### Visualisations
#
# Heatmap to analyse the correlations between variables

# %%
# Numeric_only=True, as .corr() can only take float or int 
correlation_matrix = df1.corr(numeric_only=True)
plt.figure(figsize=(13, 13))  
sns.heatmap(correlation_matrix, annot=True, cmap='crest', fmt='.2f', linewidths=0.5,annot_kws={"size": 8})
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# #### Some Insights from Heatmap:
# * Order Item Product Price and Order Item Profit Ratio (0.79):
#     * Suggests that higher-priced items tend to have a higher profit ratio.
# * Order Item Profit Ratio and Sales (0.62):
#     * Indicates that higher sales are moderately linked to better profitability.
# * Benefit per order and Order Item Profit Ratio (0.82):
#     * Shows that more profitable orders yield higher benefits.
# * Order Item Quantity and Sales (-0.08):
#     * This weak negative correlation suggests that higher sales do not necessarily come from larger quantities of items, potentially due to high-priced, low-quantity products.
# * Year/Month with Business Metrics (~0.01 to 0.14):
#     * Little correlation between time-related variables (year, month) and most variables, suggests sales and discounts are not heavily influenced by time trends in this dataset.
#
#
# ##### Delivery insights
# * Days for Shipping (real) & Days for Shipping (scheduled) (0.52):
#     * Moderate positive correlation, scheduled shipping times moderately predict actual shipping times, but delays do occur.
# * Late Delivery Risk & Days for Shipping (real) (-0.41):
#     * Late delivery risk decreases as actual shipping days increase, suggests longer shipping durations may reduce the risk of late deliveries.
# * Late_delivery_risk and Days for shipment (scheduled) (-0.37):
#     * Suggests that better scheduling reduces the risk of late delivery.

# %% [markdown]
# #### Analysing Revenue Trends

# %%
# Plotting the revenue trend over years
annual_revenue.plot(kind='line', figsize=(12, 6), color='red',marker="o")

plt.title('Annual Revenue Trend Over Time')
plt.xlabel('Year')
plt.ylabel('Total Revenue (in millions)')
plt.gca().yaxis.set_major_formatter(ScalarFormatter())

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plotting the revenue trend over years
Q1_rev = monthly_revenue.quantile(0.25)
Q3_rev = monthly_revenue.quantile(0.75)

# %%
monthly_revenue.plot(kind='line', figsize=(12, 6), color='tomato',marker="o")

monthly_revenue['YearMonth'] = pd.to_datetime(monthly_revenue['YearMonth'], format='%Y-%m')

plt.title('Annual Revenue Trend Over Time')
plt.xlabel('Month-Year')
plt.ylabel('Total Revenue')
# plt.axhline(y=Q1_rev, color='b', linestyle='--', label='1st Quartile')
# plt.axhline(y=Q3_rev, color='b', linestyle='--', label='3rd Quartile')

plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# File c:\Users\ameli\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\period.py:481, in PeriodIndex.get_loc(self, key)
#     480 try:
# --> 481     parsed, reso = self._parse_with_reso(key)
#     482 except ValueError as err:
#     483     # A string with invalid format
#
# File c:\Users\ameli\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\datetimelike.py:293, in DatetimeIndexOpsMixin._parse_with_reso(self, label)
#     291     label = str(label)
# --> 293 parsed, reso_str = parsing.parse_datetime_string_with_reso(label, freqstr)
#     294 reso = Resolution.from_attrname(reso_str)
#
# File parsing.pyx:442, in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# File parsing.pyx:666, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# DateParseError: Unknown datetime string format, unable to parse: YearMonth
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[111], line 3
#       1 monthly_revenue.plot(kind='line', figsize=(12, 6), color='tomato',marker="o")
# ----> 3 monthly_revenue['YearMonth'] = pd.to_datetime(monthly_revenue['YearMonth'], format='%Y-%m')
#       5 plt.title('Annual Revenue Trend Over Time')
#       6 plt.xlabel('Month-Year')
#
# File c:\Users\ameli\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File c:\Users\ameli\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File c:\Users\ameli\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\period.py:484, in PeriodIndex.get_loc(self, key)
#     481     parsed, reso = self._parse_with_reso(key)
#     482 except ValueError as err:
#     483     # A string with invalid format
# --> 484     raise KeyError(f"Cannot interpret '{key}' as period") from err
#     486 if self._can_partial_date_slice(reso):
#     487     try:
#
# KeyError: "Cannot interpret 'YearMonth' as period"

# %% [markdown]
# Anlaysing sales trend by customer segments to identify which segment might be contributing to the decreasing revenue

# %%
df1['Customer Segment'].value_counts().sort_index().plot(kind='pie', title='Sales by Customer Segments', autopct='%1.1f%%', startangle=120, figsize=(8, 8), colors = sns.color_palette("Set3"))
plt.rcParams['figure.figsize'] = (14, 6)
plt.gca().get_yaxis().set_visible(False)
plt.show()

# %%
# Group data by customer segment and year
customer_segment = df1.groupby(['Customer Segment', 'year'])['Sales'].sum().reset_index()

# Pivot the data for easier plotting
pivot_customer_segment = customer_segment.pivot(index='year', columns='Customer Segment', values='Sales')

# Plot the data
plt.figure(figsize=(12, 8))

for segment in pivot_customer_segment.columns:
    plt.plot(pivot_customer_segment.index, pivot_customer_segment[segment], label=segment, marker='o')

plt.title('Sales by Customer Segment Over the Years', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.legend(title='Customer Segment')
plt.grid(True)
plt.show()

# %% [markdown]
# From the above, Consumer Segment is the largest contributor to the revenue. <br/>
# We will perform further analysis with the focus on Consumer Segment to investigate what may result in the significant decrease in sales.

# %%
# Filtering data further to only focus on 'Consumer' in 'Customer Segment'

df1_consumer = df1[df1['Customer Segment'].isin(['Consumer'])]
df1_consumer.head(3)
# Out:
#       Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 1174  CASH                         2                              1
# 1177  CASH                         3                              4
# 1188  CASH                         2                              2
#
#       Benefit per order  Sales per customer   Delivery Status  \
# 1174              78.66              262.20     Late delivery
# 1177             109.67              324.47  Advance shipping
# 1188             136.51              278.59  Shipping on time
#
#       Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 1174                   1           73  Sporting Goods        Caguas  ...
# 1177                   0           73  Sporting Goods         Tampa  ...
# 1188                   0           73  Sporting Goods     Irvington  ...
#
#      Order State  Order Status  Product Name shipping date (DateOrders)  \
# 1174     Yakarta        CLOSED  Smart watch             12/6/2017 14:37
# 1177     Yakarta        CLOSED  Smart watch             12/7/2017 13:34
# 1188      Rangún        CLOSED  Smart watch              12/6/2017 9:43
#
#        Shipping Mode          order_date  year  month  Revenue YearMonth
# 1174     First Class 2017-12-04 14:37:00  2017     12   327.75   2017-12
# 1177  Standard Class 2017-12-04 13:34:00  2017     12   327.75   2017-12
# 1188    Second Class 2017-12-04 09:43:00  2017     12   327.75   2017-12
#
# [3 rows x 40 columns]

# %% [markdown]
# #### Analysis by Department

# %%
# Grouping by Department to calculate average profits and total sales
df1_consumer["Department Profit"] = df1_consumer['Order Item Profit Ratio'] * df1_consumer['Sales']

department_stats = df1_consumer.groupby('Department Name').agg(
    avg_profit_dept=('Department Profit', 'mean'),
    total_sales=('Sales', 'sum')
).sort_values(by='avg_profit_dept', ascending=False)

print(department_stats)
# Out:
#                     avg_profit_dept    total_sales
# Department Name
# Technology               116.070297   57383.200377
# Footwear                  39.167776  234262.819912
# Fan Shop                  32.664590  936134.261768
# Fitness                   26.229743   16874.250183
# Apparel                   24.211833  451516.544802
# Discs Shop                22.674484    9125.270131
# Golf                      16.722893  247562.761160
# Outdoors                  13.398098   70469.470438
# Book Shop                  4.673511     839.159998
# Pet Shop                   0.347530    1434.800026
# Health and Beauty        -85.763039    4395.600127
# C:\Users\ameli\AppData\Local\Temp\ipykernel_19720\978010826.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_consumer["Department Profit"] = df1_consumer['Order Item Profit Ratio'] * df1_consumer['Sales']

# %%
colors = ['seagreen' if val > 0 else 'tomato' for val in department_stats['avg_profit_dept']]

# Plot the bar chart
plt.figure(figsize=(16, 8))
barplot = sns.barplot(x=department_stats.index, 
                      y=department_stats['avg_profit_dept'], 
                      palette=colors)

plt.title('Average Profit by Department')
plt.xticks(rotation=45)
plt.ylabel('Average Profit')
plt.xlabel('Department')

for p in barplot.patches:
    barplot.annotate(f'{int(p.get_height())}',  
                     (p.get_x() + p.get_width()/2., p.get_height()),  
                     ha = 'center', va = 'bottom',  
                     fontsize = 7, color = 'black',  
                     xytext = (0, 2), 
                     textcoords = 'offset points')
    
plt.show()
# Out:
# C:\Users\ameli\AppData\Local\Temp\ipykernel_19720\2564616018.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x=department_stats.index,

# %% [markdown]
# The data seems to be abnormal starting from '2017-09', where technology department started to have sales value. <br/>
# Inconclusive but speculations we have includes:
# * possibility of other sales data being recorded wrongly into Technology department
# * possibility where Techonology product was the new hot thing that garnered huge sales from consumer for a short period of time
#
# However, this causes uncertainty in our analysis, to ensure reliability, we will drop data from '2017-09'

# %%
# Filter out data from 2017-09 onwards
df2 = df1_consumer[df1_consumer['YearMonth'] < '2017-09-01']

# Check the filtered dataset
df2
# Out:
#         Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 2586    CASH                         4                              2
# 2588    CASH                         2                              1
# 2593    CASH                         4                              4
# 2636    CASH                         3                              4
# 2646    CASH                         6                              4
# ...      ...                       ...                            ...
# 180451  CASH                         3                              2
# 180452  CASH                         3                              2
# 180467  CASH                         2                              1
# 180496  CASH                         2                              4
# 180498  CASH                         3                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# 2586                20.28               42.24     Late delivery
# 2588               -16.72               41.80     Late delivery
# 2593                51.74              105.60  Shipping on time
# 2636                14.72               43.56  Advance shipping
# 2646                12.94               43.12     Late delivery
# ...                   ...                 ...               ...
# 180451              36.00              359.98     Late delivery
# 180452            -237.59              351.98     Late delivery
# 180467              27.90              371.98     Late delivery
# 180496             145.19              399.98  Advance shipping
# 180498            -337.10              391.98  Advance shipping
#
#         Late_delivery_risk  Category Id Category Name  Customer City  ...  \
# 2586                     1            7        Hockey         Caguas  ...
# 2588                     1            7        Hockey         Caguas  ...
# 2593                     0            7        Hockey         Caguas  ...
# 2636                     0            7        Hockey         Caguas  ...
# 2646                     1            7        Hockey        Chicago  ...
# ...                    ...          ...           ...            ...  ...
# 180451                   1           45       Fishing     Germantown  ...
# 180452                   1           45       Fishing     Germantown  ...
# 180467                   1           45       Fishing  Panorama City  ...
# 180496                   0           45       Fishing     Costa Mesa  ...
# 180498                   0           45       Fishing    Lindenhurst  ...
#
#                   Order State  Order Status  \
# 2586             Buenos Aires        CLOSED
# 2588                São Paulo        CLOSED
# 2593                  Managua        CLOSED
# 2636    Rabat-Salé-Zemur-Zaer        CLOSED
# 2646                    Thiès        CLOSED
# ...                       ...           ...
# 180451                  Gansu        CLOSED
# 180452                  Gansu        CLOSED
# 180467            Maharashtra        CLOSED
# 180496               Shanghái        CLOSED
# 180498     Sumatra Meridional        CLOSED
#
#                                      Product Name shipping date (DateOrders)  \
# 2586                Nike Dri-FIT Crew Sock 6 Pack            2/24/2017 14:08
# 2588                Nike Dri-FIT Crew Sock 6 Pack            2/18/2017 23:57
# 2593                Nike Dri-FIT Crew Sock 6 Pack             2/13/2017 8:22
# 2636                Nike Dri-FIT Crew Sock 6 Pack           10/15/2016 13:27
# 2646                Nike Dri-FIT Crew Sock 6 Pack             9/14/2016 3:41
# ...                                           ...                        ...
# 180451  Field & Stream Sportsman 16 Gun Fire Safe            1/22/2016 17:09
# 180452  Field & Stream Sportsman 16 Gun Fire Safe            1/22/2016 17:09
# 180467  Field & Stream Sportsman 16 Gun Fire Safe            1/20/2016 19:05
# 180496  Field & Stream Sportsman 16 Gun Fire Safe            1/18/2016 22:14
# 180498  Field & Stream Sportsman 16 Gun Fire Safe            1/19/2016 19:05
#
#          Shipping Mode          order_date  year  month  Revenue YearMonth
# 2586      Second Class 2017-02-20 14:08:00  2017      2    44.00   2017-02
# 2588       First Class 2017-02-16 23:57:00  2017      2    44.00   2017-02
# 2593    Standard Class 2017-02-09 08:22:00  2017      2   110.00   2017-02
# 2636    Standard Class 2016-10-12 13:27:00  2016     10    44.00   2016-10
# 2646    Standard Class 2016-09-08 03:41:00  2016      9    44.00   2016-09
# ...                ...                 ...   ...    ...      ...       ...
# 180451    Second Class 2016-01-19 17:09:00  2016      1   399.98   2016-01
# 180452    Second Class 2016-01-19 17:09:00  2016      1   399.98   2016-01
# 180467     First Class 2016-01-18 19:05:00  2016      1   399.98   2016-01
# 180496  Standard Class 2016-01-16 22:14:00  2016      1   399.98   2016-01
# 180498  Standard Class 2016-01-16 19:05:00  2016      1   399.98   2016-01
#
# [9171 rows x 40 columns]

# %% [markdown]
# Running the same trend analysis with the cleaned data

# %%
# Extract year and month for grouping
df2['YearMonth'] = df2['order_date'].dt.to_period('M')  # Combines year and month into YYYY-MM format

# Group sales data by Department and YearMonth
dept_sales_over_time = df2.groupby(['Department Name', 'YearMonth'])['Sales'].sum().reset_index()

# Convert 'YearMonth' from Period to string for plotting
dept_sales_over_time['YearMonth'] = dept_sales_over_time['YearMonth'].astype(str)

# Plotting the sales trends
plt.figure(figsize=(14, 8))
# Loop through unique departments to plot individual lines
for department in dept_sales_over_time['Department Name'].unique():
    department_data = dept_sales_over_time[
        dept_sales_over_time['Department Name'] == department
    ]
    plt.plot(
        department_data['YearMonth'],
        department_data['Sales'],
        marker='o',
        label=department,
    )

# Formatting the plot
plt.title('Sales of Different Departments Over Time', fontsize=16)
plt.xlabel('Time (Year-Month)', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.legend(loc='upper right', title='Departments', fontsize=10)
plt.xticks(rotation=45)
plt.grid(alpha=0.3)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\ameli\AppData\Local\Temp\ipykernel_19720\2686242288.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['YearMonth'] = df2['order_date'].dt.to_period('M')  # Combines year and month into YYYY-MM format

# %% [markdown]
# Fan Shop Department shows the greatest contribution to sales <br/>
# Outdoors and Fitness are the lowest contributors to sales <br/>
#
# This could be due to Consumer demographics or management inefficiency by the respective department. Current data is inconclusive, require further analysis.

# %%
# Group data by department and calculate total sales and profit
department_data = df2.groupby('Department Name').agg({'Sales': 'sum', 'Benefit per order': 'sum'}).reset_index()

# Create the figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Bar chart for sales
bar_width = 0.4
bar_positions = np.arange(len(department_data['Department Name']))

bars = ax.bar(bar_positions, department_data['Sales'], width=bar_width, label='Sales', color='skyblue')

# Line chart for profit
ax.plot(bar_positions, department_data['Benefit per order'], label='Profit', color='red', marker='o', linewidth=2)

# Set axis labels and title

ax.set_ylabel('Value (Sales and Profit)', color='blue')
ax.set_title('Sales and Profit by Department')
ax.set_xticks(bar_positions)
ax.set_xticklabels(department_data['Department Name'], rotation=45, ha='right')
ax.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# This provides insights to how the profit margins are low considering high sales amount. This could suggest improvements required in reducing costs to raise profits.

# %% [markdown]
# #### Analysis by Category

# %%
# Calculate profit for each row
df2['Product Profit'] = df2['Order Item Profit Ratio'] * df2['Sales']
cat_profit_df = df2.groupby('Category Name').agg({'Product Profit': 'sum'}).reset_index()
# cat_profit_df.rename(columns={'Product Profit': 'Category Profit'}, inplace=True)

cat_profit_df
# Out:
# C:\Users\ameli\AppData\Local\Temp\ipykernel_19720\595688495.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Product Profit'] = df2['Order Item Profit Ratio'] * df2['Sales']
#            Category Name  Product Profit
# 0            Accessories        1,050.08
# 1        As Seen on  TV!         -280.97
# 2    Baseball & Softball          926.22
# 3           Boxing & MMA          872.25
# 4       Camping & Hiking       27,223.19
# 5       Cardio Equipment       27,568.15
# 6                 Cleats       34,874.59
# 7            Electronics        3,050.07
# 8                Fishing       49,373.53
# 9    Fitness Accessories         -348.85
# 10        Girls' Apparel          989.23
# 11          Golf Apparel          200.17
# 12     Golf Bags & Carts           47.60
# 13            Golf Balls          538.30
# 14           Golf Gloves          584.63
# 15            Golf Shoes         -286.24
# 16                Hockey          375.34
# 17    Hunting & Shooting           11.88
# 18  Indoor/Outdoor Games       22,973.31
# 19      Kids' Golf Clubs         -528.51
# 20              Lacrosse          249.95
# 21        Men's Footwear       21,523.75
# 22      Men's Golf Clubs          120.98
# 23         Shop By Sport        8,108.43
# 24                Soccer           32.40
# 25     Strength Training          171.99
# 26      Tennis & Racquet          453.05
# 27              Trade-In           23.89
# 28          Water Sports       14,383.28
# 29       Women's Apparel       19,133.50
# 30    Women's Golf Clubs          504.65

# %% [markdown]
# Identifying Product Category that contributes most to profits

# %%
# Sort the DataFrame by 'Product Profit' for better visualization
cat_profit_df_sorted = cat_profit_df.sort_values(by='Product Profit', ascending=False)

# Create the bar plot
plt.figure(figsize=(14, 8))
sns.barplot(x='Product Profit', y='Category Name', data=cat_profit_df_sorted, palette='viridis')

# Adding title and labels
plt.title('Profit by Category', fontsize=16)
plt.xlabel('Profit ($)', fontsize=12)
plt.ylabel('Category Name', fontsize=12)
plt.axvline(x=0,color='grey',linestyle="--")

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ameli\AppData\Local\Temp\ipykernel_19720\2379408017.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Product Profit', y='Category Name', data=cat_profit_df_sorted, palette='viridis')

# %%
# Calculate profit for each row
df2['Product Profit'] = df2['Order Item Profit Ratio'] * df2['Sales']
cat_avgprofit_df = df2.groupby('Category Name').agg({'Product Profit': 'mean'}).reset_index()

cat_avgprofit_df
# Out:
# C:\Users\ameli\AppData\Local\Temp\ipykernel_19720\109768370.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Product Profit'] = df2['Order Item Profit Ratio'] * df2['Sales']
#            Category Name  Product Profit
# 0            Accessories           10.29
# 1        As Seen on  TV!         -140.49
# 2    Baseball & Softball           24.37
# 3           Boxing & MMA           45.91
# 4       Camping & Hiking           38.45
# 5       Cardio Equipment           40.72
# 6                 Cleats           26.30
# 7            Electronics           18.26
# 8                Fishing           52.69
# 9    Fitness Accessories          -31.71
# 10        Girls' Apparel           16.22
# 11          Golf Apparel            6.46
# 12     Golf Bags & Carts           47.60
# 13            Golf Balls            5.73
# 14           Golf Gloves           10.83
# 15            Golf Shoes          -11.45
# 16                Hockey           10.43
# 17    Hunting & Shooting            0.44
# 18  Indoor/Outdoor Games           22.22
# 19      Kids' Golf Clubs          -35.23
# 20              Lacrosse           14.70
# 21        Men's Footwear           17.82
# 22      Men's Golf Clubs            6.72
# 23         Shop By Sport           14.13
# 24                Soccer            6.48
# 25     Strength Training           43.00
# 26      Tennis & Racquet           23.84
# 27              Trade-In            0.61
# 28          Water Sports           17.60
# 29       Women's Apparel           17.52
# 30    Women's Golf Clubs           38.82

# %%
# Sort the DataFrame by 'Product Profit' for better visualization
cat_avgprofit_df_sorted = cat_avgprofit_df.sort_values(by='Product Profit', ascending=False)

# Create the bar plot
plt.figure(figsize=(14, 8))
sns.barplot(x='Product Profit', y='Category Name', data=cat_avgprofit_df_sorted, palette='viridis')

# Adding title and labels
plt.title('Average Profit by Category', fontsize=16)
plt.xlabel('Average Profit ($)', fontsize=12)
plt.ylabel('Category Name', fontsize=12)
plt.axvline(x=0,color='black')

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ameli\AppData\Local\Temp\ipykernel_19720\3020102294.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Product Profit', y='Category Name', data=cat_avgprofit_df_sorted, palette='viridis')

# %%
colors = ['green' if val > 0 else 'red' for val in category_stats['avg_profit_cat']]

df_sorted = df2.sort_values(by='Category Profit', ascending=False)

plt.figure(figsize=(16, 8))
sns.barplot(y='Category Name',x='Category Profit', data = df_sorted, palette ='viridis')


plt.title('Profit by Category', fontsize=16)
plt.xlabel('Profit ($)', fontsize=12)
plt.ylabel('Category Name', fontsize=12)

# Display the plot
plt.tight_layout()
plt.show()

# %%
colors = ['green' if val > 0 else 'red' for val in category_stats['avg_profit_cat']]

# Plot the bar chart
plt.figure(figsize=(16, 8))
sns.barplot(
    x=category_stats.index, 
    y=category_stats['avg_profit_cat'], 
    palette=colors)

plt.title('Average Profit by Category')
plt.xticks(rotation=45)
plt.ylabel('Average Profit')
plt.xlabel('Category')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ameli\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cat_profit_df'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 colors = ['green' if val > 0 else 'red' for val in category_stats['cat_profit_df']]
#       3 # Plot the bar chart
#       4 plt.figure(figsize=(16, 8))
#
# File c:\Users\ameli\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\ameli\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'cat_profit_df'

# %% [markdown]
# #### Delivery Data Analysis

# %%
df2['Delivery Status'].unique()
# Out:
# array(['Late delivery', 'Shipping on time', 'Advance shipping'],
#       dtype=object)

# %% [markdown]
# Pie Chart of Different Delivery Status

# %%
status_counts = df2['Delivery Status'].value_counts()

# To assign Late delivery as the seaborn palette red
color = sns.color_palette("Set2")
palette = sns.color_palette([color[1], color[0], color[2]])

plt.figure(figsize=(6, 6))
plt.pie(status_counts, 
        labels=status_counts.index, 
        autopct='%1.1f%%', 
        startangle=180, 
        colors=palette)
plt.title("Percentage of Different Delivery Status")
plt.axis('equal')
plt.show()

# %% [markdown]
# Investigating relationship between different Shipping Modes with Delivery Status

# %%
shipping_ord = ['First Class','Second Class','Standard Class','Same Day']

plt.figure(figsize=(8, 5))
barplot = sns.countplot(x='Delivery Status', hue='Shipping Mode', data=df2, palette='Set2', hue_order = shipping_ord)

plt.title('Delivery Status by Shipping Mode', fontsize=14)
plt.xlabel('Delivery Status')
plt.ylabel('Number of Deliveries')
plt.legend(bbox_to_anchor=(1.01,1),loc="upper left",borderaxespad=0, labels = shipping_ord)

# Total delivery count on top of each bar
for p in barplot.patches:
    barplot.annotate(f'{int(p.get_height())}',  
                     (p.get_x() + p.get_width()/2., p.get_height()),  
                     ha = 'center', va = 'bottom',  
                     fontsize = 7, color = 'black',  
                     xytext = (0, 2), 
                     textcoords = 'offset points')

plt.show()

# %% [markdown]
# #### Insights from analysis
# * First Class shipping is unreliable, always result in Late Delivery
#
# Potential contribution in reduced sales due to unreliable delivery with over 50% of orders delivered late.
